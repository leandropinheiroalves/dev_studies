# %%
import pandas as pd

# %% [markdown]
# ## Criando um dataframe a partir de um dicionário

# %%
# dataframe = pd.DataFrame()
venda = {'data': ['15/02/2021', '16/02/2021'],
         'valor': [500, 300],
         'produto': ['feijao', 'arroz'],
         'qtde': [50, 70]
        }
vendas_df = pd.DataFrame(venda)

# %% [markdown]
# ## Visualização dos Dados
#
# - print
# - display

# %%
display(vendas_df)
# Out:
#          data  valor produto  qtde
# 0  15/02/2021    500  feijao    50
# 1  16/02/2021    300   arroz    70

# %% [markdown]
# ## Importando arquivos e bases de dados

# %%
vendas_df = pd.read_excel('tabela1.xlsx', sheet_name='Products')
display(vendas_df)
#print(vendas_df.shape)
#display(vendas_df.describe())
# Out:
#     ProductID                      ProductName  SupplierID  CategoryID  \
# 0           1                            Chais           1           1
# 1           2                            Chang           1           1
# 2           3                    Aniseed Syrup           1           2
# 3           4     Chef Anton's Cajun Seasoning           2           2
# 4           5           Chef Anton's Gumbo Mix           2           2
# ..        ...                              ...         ...         ...
# 72         73                       Röd Kaviar          17           8
# 73         74                    Longlife Tofu           4           7
# 74         75             Rhönbräu Klosterbier          12           1
# 75         76                     Lakkalikööri          23           1
# 76         77  Original Frankfurter grüne Soße          12           2
#
#                    Unit  Price
# 0    10 boxes x 20 bags     18
# 1    24 - 12 oz bottles     19
# ...

# %% [markdown]
# ## Pegar 1 coluna (e os pd.Series)

# %%
produtos = vendas_df[['ProductName', 'SupplierID']]
display(produtos)
# Out:
#                         ProductName  SupplierID
# 0                             Chais           1
# 1                             Chang           1
# 2                     Aniseed Syrup           1
# 3      Chef Anton's Cajun Seasoning           2
# 4            Chef Anton's Gumbo Mix           2
# ..                              ...         ...
# 72                       Röd Kaviar          17
# 73                    Longlife Tofu           4
# 74             Rhönbräu Klosterbier          12
# 75                     Lakkalikööri          23
# 76  Original Frankfurter grüne Soße          12
#
# [77 rows x 2 columns]

# %% [markdown]
# ## .loc, um método muito importante
#
# - Pegar 1 linha
# - Pegar linhas de acordo com alguma condição
# - Pegar linhas e colunas específicas
# - Pegar 1 valor específico

# %%
# pegar uma linha
#display(vendas_df.loc[1:5])

#pegar linhas que correspondem a  uma condição

display(vendas_df.loc[vendas_df['SupplierID'] == 1])
# Out:
#    ProductID    ProductName  SupplierID  CategoryID                 Unit Price
# 0          1          Chais           1           1   10 boxes x 20 bags    18
# 1          2          Chang           1           1   24 - 12 oz bottles    19
# 2          3  Aniseed Syrup           1           2  12 - 550 ml bottles    10

# %% [markdown]
# ## Adicionar 1 coluna

# %%
#import sqlite3

#conexao = sqlite3.connect('teste.db')

#df_1 = pd.read_excel('tabela1.xlsx', sheet_name='Customers')
#df_1.to_sql('Customers', conexao)

#lista = ['Customers', 'Categories', 'Employees', 'OrderDetails', 'Orders', 'Products', 'Shippers', 'Suppliers']

#for i in lista:
#    df_total = pd.read_excel('tabela1.xlsx', sheet_name=i)
#    df_total.to_sql(i, conexao)
